# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # problem 1

# %%
hurcane=pd.read_csv('Hurricanes.csv')
plt.figure(figsize=(10,7))
plt.bar(hurcane['Year'], hurcane['Hurricanes'])
plt.show()

# %% [markdown]
# # problem 2

# %%
citytemp=pd.read_csv('CityTemps.csv')
plt.hist([citytemp['San Francisco'],citytemp['Moscow']])
plt.show()

# %% [markdown]
# # problem 3

# %%
txt = pd.read_csv("data_file.txt",delimiter=',')
txt.to_csv('M4_assign_dataset.csv', index=False)

df=pd.read_csv('M4_assign_dataset.csv')
df.head()
# Out:
#    account_number                           name item_code category  quantity  \
# 0          296809                    Carroll PLC  QN-82852     Belt        13
# 1           98022              Heidenreich-Bosco  MJ-21460    Shoes        19
# 2          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12
# 3           93356                  Waters-Walker  AS-93055    Shirt         5
# 4          659366                  Waelchi-Fahey  AS-93055    Shirt        18
#
#    unit price  net_price                 date
# 0       44.48     578.24  2014-09-27 07:13:03
# 1       53.62    1018.78  2014-07-29 02:10:44
# 2       24.16     289.92  2014-03-01 10:51:24
# 3       82.68     413.40  2013-11-17 20:41:11
# 4       99.64    1793.52  2014-01-03 08:14:27

# %% [markdown]
# # problem 4

# %%
x=[1,2,3,4]
y=[20,21,20.5,20.8]
plt.figure(figsize=(4,5), dpi=100)
plt.title("Simple Graph")
plt.xlabel('The X Axis')
plt.ylabel('The Y Axis')
plt.xlim(-1,7)
plt.xticks([-1,0,1,2,3,4,5,6,7])
plt.plot(x,y,'sr--')
plt.rc('legend')
plt.xticks(fontsize=14)
plt.show()

# %%
x1=np.random.randint(1,70, 50)
y1=np.random.randint(30,100,50)
plt.scatter(x1,y1)
plt.show()

# %%
df = pd.DataFrame({'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
                  'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
                  'female': [0, 1, 1, 0, 1],
                  'age': [42, 52, 36, 24, 73], 
                  'preTestScore': [4, 24, 31, 2, 3],
                  'postTestScore': [25, 94, 57, 62, 70]})


plt.figure(figsize=(7,5))
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['age'])
plt.show()

# %%
plt.scatter(df['preTestScore'], df['postTestScore'], s=300, c=df['female'])
